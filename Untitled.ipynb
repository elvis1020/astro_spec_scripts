# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib nbagg

# %%
global mt
global ag
global cE
global cMm
global pcurve
global ptxt
global fidu_met

# %%
def CMbuild(filein):
    data = np.genfromtxt(filein, unpack=True)
    age = data[1]
    isochrones = {}
    lastage = 0
    for n, i in enumerate(age):
        if i != lastage:
            isochrones[i] = [[], []]
        B = data[24][n]
        V = data[25][n]
        if V < 25:
            isochrones[i][0].append(B)
            isochrones[i][1].append(V)
        lastage = i
    return isochrones

# %%
def HRbuild(filein):
    data = np.genfromtxt(filein, unpack=True)
    age = data[1]
    isochrones = {}
    lastage = 0
    for n, i in enumerate(age):
        if i != lastage:
            isochrones[i] = [[], []]
        L = data[4][n]
        Teff = data[5][n]
        if data[9][n] > 0.4:
            isochrones[i][0].append(L)
            isochrones[i][1].append(Teff)
        lastage = i
    return isochrones

# %%
def plotiso(ax, met, age, E, Mm, Vlim):
    global ptxt
    global pcurve
    try:
        pcurve.remove()
        ax.texts.remove(ptxt)
        plt.draw()
    except:
        pass
    Av = 3.1*E
    B = np.array(metset[met][age][0]) + Mm + Av
    V = np.array(metset[met][age][1]) + Mm + Av
    BV = B - V + E
    pcurve = ax.plot(BV, V, 'r-')[0]
    ax.set_ylim([Vlim, min(V)-2])
    distance = 10**((Mm + 5) / 5)
    ptxt = ax.text(0.01, 0.01, met+'; %6.3fGyr; E(B-V)=%4.3f; (M-m)0=%3.1f; d=%7.1fpc'%(age/1E9, E, Mm, distance), transform=ax.transAxes, color='green')

# %%
def plothr(ax, met, age, style, Vlim):
    L = np.array(metset[met][age][0])
    T = np.array(metset[met][age][1])
    pcurve = ax.plot(T, L, style)[0]

# %%
def fiducial(ax, met, E, Mm, Vlim):
    global fidu_met
    try:
        for i in fidu_met:
            i.remove()
    except:
        pass
    Av = 3.1*E
    fidu_met = []
    for a in ages:
        B = np.array(metset[met][a][0]) + Mm + Av
        V = np.array(metset[met][a][1]) + Mm + Av
        BV = B - V + E
        fidu_met.append(ax.plot(BV, V, 'k-', alpha=0.05)[0])
    ax.set_ylim([Vlim, min(V)-2])

# %%
def stepmet(direct, ax):
    global mt
    mets = sorted(metset.keys())
    idx = mets.index(mt)
    if direct == 'up':
        mt = mets[idx + 1]
    if direct == 'down':
        mt = mets[idx - 1]
    pcurve = plotiso(axcm, mt, ag, cE, cMm, lim)
    print mt

# %%
def stepage(direct, ax):
    global ag
    idx = ages.index(ag)
    if direct == 'up':
        ag = ages[idx + 1]
    if direct == 'down':
        ag = ages[idx - 1]
    pcurve = plotiso(axcm, mt, ag, cE, cMm, lim)
    print ag

# %%
def setpars(excess, dist, ax):
    global cE
    global cMm
    cE = excess
    cMm = dist
    pcurve = plotiso(axcm, mt, ag, cE, cMm, lim)

# %%
Z_0001 = CMbuild('Z_0.0001.dat')
Z_001 = CMbuild('Z_0.001.dat')
Z_006 = CMbuild('Z_0.006.dat')
Z_010 = CMbuild('Z_0.010.dat')
Z_015 = CMbuild('Z_0.015.dat')
Z_020 = CMbuild('Z_0.020.dat')
metset = {'Z_0001': Z_0001, 'Z_001':Z_001, 'Z_006': Z_006, 'Z_010': Z_010, 'Z_015': Z_015, 'Z_020': Z_020}
ages = sorted(Z_020.keys())
print(ages)
# Out:
# [3980000.0, 4470000.0, 5010000.0, 5620000.0, 6310000.0, 7080000.0, 7940000.0, 8910000.0, 10000000.0, 11200000.0, 12600000.0, 14100000.0, 15800000.0, 17800000.0, 20000000.0, 22400000.0, 25100000.0, 28200000.0, 31600000.0, 35500000.0, 39800000.0, 44700000.0, 50100000.0, 56200000.0, 63100000.0, 70800000.0, 79400000.0, 89100000.0, 100000000.0, 112000000.0, 126000000.0, 141000000.0, 158000000.0, 178000000.0, 200000000.0, 224000000.0, 251000000.0, 282000000.0, 316000000.0, 355000000.0, 398000000.0, 447000000.0, 501000000.0, 562000000.0, 631000000.0, 708000000.0, 794000000.0, 891000000.0, 1000000000.0, 1120000000.0, 1260000000.0, 1410000000.0, 1580000000.0, 1780000000.0, 2000000000.0, 2240000000.0, 2510000000.0, 2820000000.0, 3160000000.0, 3550000000.0, 3980000000.0, 4470000000.0, 5010000000.0, 5620000000.0, 6310000000.0, 7080000000.0, 7940000000.0, 8910000000.0, 10000000000.0, 11200000000.0, 12600000000.0]

# %%
Z_0001 = HRbuild('Z_0.0001.dat')
Z_001 = HRbuild('Z_0.001.dat')
Z_006 = HRbuild('Z_0.006.dat')
Z_010 = HRbuild('Z_0.010.dat')
Z_015 = HRbuild('Z_0.015.dat')
Z_020 = HRbuild('Z_0.020.dat')
metset = {'Z_0001': Z_0001, 'Z_001':Z_001, 'Z_006': Z_006, 'Z_010': Z_010, 'Z_015': Z_015, 'Z_020': Z_020}
ages = sorted(Z_020.keys())

# %%
fig = plt.figure('C-M')
axcm = fig.add_subplot(111)
axcm.invert_yaxis()
axcm.set_xlabel('B-V')
axcm.set_ylabel('V')
plt.ion()
# Out:
# <img src="data:image/png;base64,...">

# %%
cldata = np.genfromtxt('cluster_02.dat', unpack=True)
axcm.plot(cldata[1], cldata[0], 'k.')
pcurve = ''
ptxt = ''
fidu_met = []

# %%
mt = 'Z_0001'
ag = 8910000000
cE = 0.1
cMm = 14.7
lim = 24
plotiso(axcm, mt, ag, cE, cMm, lim)

# %%
stepmet('up', axcm)
# Out:
# Z_010

# %%
stepmet('down', axcm)
# Out:
# Z_006

# %%
stepage('up', axcm)
# Out:
# 6310000000.0

# %%
stepage('down', axcm)
# Out:
# 5010000000.0

# %%
setpars(0.01, 17.8, axcm)

# %%
fiducial(axcm, mt, cE, cMm, lim)

# %%
for i in fidu_met:
    i.remove()

# %%
fi2 = plt.figure('isoc')
axlt = fi2.add_subplot(111)
axlt.invert_xaxis()
axlt.set_xlabel('log(Teff)')
axlt.set_ylabel('L')
plt.ion()
# Out:
# <img src="data:image/png;base64,...">

# %%
#10 Myr, 100 Myr, 1 Gyr, 5 Gyr e 13 Gyr
#1000000000 5010000000 12600000000
#0.0001, 0.001, 0.010, 0.015
Zs = ['Z_0001', 'Z_001', 'Z_010', 'Z_015']
ids = [10000000, 100000000, 1000000000, 5010000000, 12600000000]
styles = ['r-', 'b-', 'm-', 'g-']
sty = -1
for z in Zs:
    sty += 1
    for i in ids:
        plothr(axlt, z, i, styles[sty], 24)
